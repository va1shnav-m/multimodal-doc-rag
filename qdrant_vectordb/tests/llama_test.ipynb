# %%
from llama_index.core.node_parser import HierarchicalNodeParser
from llama_index.core.node_parser import get_leaf_nodes

print("OK")
# Out:
# OK

# %%
from llama_index.core.retrievers import AutoMergingRetriever

print("Auto Merge OK")
# Out:
# Auto Merge OK

# %%
from llama_index.core.retrievers import RecursiveRetriever

print("Recursive OK")
# Out:
# Recursive OK

# %%
from llama_index.core.retrievers import ParentDocumentRetriever

print("Parent OK")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from llama_index.core.retrievers import ParentDocumentRetriever
#       2
#       3 print("Parent OK")
#
# ImportError: cannot import name 'ParentDocumentRetriever' from 'llama_index.core.retrievers' (C:\Users\Manasi Sabnis\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\retrievers\__init__.py)

# %%
from llama_index.core.retrievers import AutoMergingRetriever

import inspect

print(inspect.signature(AutoMergingRetriever))
# Out:
# (vector_retriever: llama_index.core.indices.vector_store.retrievers.retriever.VectorIndexRetriever, storage_context: llama_index.core.storage.storage_context.StorageContext, simple_ratio_thresh: float = 0.5, verbose: bool = False, callback_manager: Optional[llama_index.core.callbacks.base.CallbackManager] = None, object_map: Optional[dict] = None, objects: Optional[List[llama_index.core.schema.IndexNode]] = None) -> None

# %%
from llama_index.core.retrievers import RecursiveRetriever

import inspect

print(inspect.signature(RecursiveRetriever))
# Out:
# (root_id: str, retriever_dict: Dict[str, llama_index.core.base.base_retriever.BaseRetriever], query_engine_dict: Optional[Dict[str, llama_index.core.base.base_query_engine.BaseQueryEngine]] = None, node_dict: Optional[Dict[str, llama_index.core.schema.BaseNode]] = None, callback_manager: Optional[llama_index.core.callbacks.base.CallbackManager] = None, query_response_tmpl: Optional[str] = None, verbose: bool = False) -> None
